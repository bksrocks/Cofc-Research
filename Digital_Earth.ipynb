# %%
# !pip install Datacube
# !pip install deafrica_tools
# Out:
# Requirement already satisfied: Datacube in /usr/local/lib/python3.7/dist-packages (1.8.5)
# Requirement already satisfied: affine in /usr/local/lib/python3.7/dist-packages (from Datacube) (2.3.1)
# Requirement already satisfied: cloudpickle>=0.4 in /usr/local/lib/python3.7/dist-packages (from Datacube) (1.3.0)
# Requirement already satisfied: shapely>=1.6.4 in /usr/local/lib/python3.7/dist-packages (from Datacube) (1.8.1.post1)
# Requirement already satisfied: netcdf4 in /usr/local/lib/python3.7/dist-packages (from Datacube) (1.5.8)
# Requirement already satisfied: jsonschema in /usr/local/lib/python3.7/dist-packages (from Datacube) (4.3.3)
# Requirement already satisfied: pyproj>=2.5 in /usr/local/lib/python3.7/dist-packages (from Datacube) (3.2.1)
# Requirement already satisfied: distributed in /usr/local/lib/python3.7/dist-packages (from Datacube) (1.25.3)
# Requirement already satisfied: lark-parser>=0.6.7 in /usr/local/lib/python3.7/dist-packages (from Datacube) (0.12.0)
# Requirement already satisfied: sqlalchemy in /usr/local/lib/python3.7/dist-packages (from Datacube) (1.4.32)
# Requirement already satisfied: xarray>=0.9 in /usr/local/lib/python3.7/dist-packages (from Datacube) (0.18.2)
# Requirement already satisfied: toolz in /usr/local/lib/python3.7/dist-packages (from Datacube) (0.11.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from Datacube) (1.21.5)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.7/dist-packages (from Datacube) (2.8.2)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.7/dist-packages (from Datacube) (3.13)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from Datacube) (1.3.5)
# Requirement already satisfied: rasterio>=1.0.2 in /usr/local/lib/python3.7/dist-packages (from Datacube) (1.2.10)
# Requirement already satisfied: click>=5.0 in /usr/local/lib/python3.7/dist-packages (from Datacube) (7.1.2)
# Requirement already satisfied: dask[array] in /usr/local/lib/python3.7/dist-packages (from Datacube) (2.12.0)
# Requirement already satisfied: psycopg2 in /usr/local/lib/python3.7/dist-packages (from Datacube) (2.7.6.1)
# Requirement already satisfied: cachetools in /usr/local/lib/python3.7/dist-packages (from Datacube) (4.2.4)
# Requirement already satisfied: certifi in /usr/local/lib/python3.7/dist-packages (from pyproj>=2.5->Datacube) (2021.10.8)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from rasterio>=1.0.2->Datacube) (57.4.0)
# Requirement already satisfied: attrs in /usr/local/lib/python3.7/dist-packages (from rasterio>=1.0.2->Datacube) (21.4.0)
# Requirement already satisfied: cligj>=0.5 in /usr/local/lib/python3.7/dist-packages (from rasterio>=1.0.2->Datacube) (0.7.2)
# Requirement already satisfied: snuggs>=1.4.1 in /usr/local/lib/python3.7/dist-packages (from rasterio>=1.0.2->Datacube) (1.4.7)
# Requirement already satisfied: click-plugins in /usr/local/lib/python3.7/dist-packages (from rasterio>=1.0.2->Datacube) (1.1.1)
# Requirement already satisfied: pyparsing>=2.1.6 in /usr/local/lib/python3.7/dist-packages (from snuggs>=1.4.1->rasterio>=1.0.2->Datacube) (3.0.7)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas->Datacube) (2018.9)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil->Datacube) (1.15.0)
# Requirement already satisfied: msgpack in /usr/local/lib/python3.7/dist-packages (from distributed->Datacube) (1.0.3)
# Requirement already satisfied: psutil>=5.0 in /usr/local/lib/python3.7/dist-packages (from distributed->Datacube) (5.4.8)
# Requirement already satisfied: sortedcontainers!=2.0.0,!=2.0.1 in /usr/local/lib/python3.7/dist-packages (from distributed->Datacube) (2.4.0)
# Requirement already satisfied: zict>=0.1.3 in /usr/local/lib/python3.7/dist-packages (from distributed->Datacube) (2.1.0)
# Requirement already satisfied: tornado>=4.5.1 in /usr/local/lib/python3.7/dist-packages (from distributed->Datacube) (5.1.1)
# Requirement already satisfied: tblib in /usr/local/lib/python3.7/dist-packages (from distributed->Datacube) (1.7.0)
# Requirement already satisfied: heapdict in /usr/local/lib/python3.7/dist-packages (from zict>=0.1.3->distributed->Datacube) (1.0.1)
# Requirement already satisfied: importlib-resources>=1.4.0 in /usr/local/lib/python3.7/dist-packages (from jsonschema->Datacube) (5.4.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.7/dist-packages (from jsonschema->Datacube) (0.18.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from jsonschema->Datacube) (3.10.0.2)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from jsonschema->Datacube) (4.11.3)
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.7/dist-packages (from importlib-resources>=1.4.0->jsonschema->Datacube) (3.7.0)
# Requirement already satisfied: cftime in /usr/local/lib/python3.7/dist-packages (from netcdf4->Datacube) (1.6.0)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.7/dist-packages (from sqlalchemy->Datacube) (1.1.2)
# Collecting deafrica_tools
#   Downloading deafrica_tools-0.1.2-py3-none-any.whl (106 kB)
#      |████████████████████████████████| 106 kB 5.2 MB/s
# Collecting OWSLib
#   Downloading OWSLib-0.25.0-py2.py3-none-any.whl (216 kB)
#      |████████████████████████████████| 216 kB 35.1 MB/s
# Requirement already satisfied: pyproj in /usr/local/lib/python3.7/dist-packages (from deafrica_tools) (3.2.1)
# Collecting odc-ui
#   Downloading odc_ui-0.2.0a3-py3-none-any.whl (15 kB)
# Requirement already satisfied: dask in /usr/local/lib/python3.7/dist-packages (from deafrica_tools) (2.12.0)
# Requirement already satisfied: geopy in /usr/local/lib/python3.7/dist-packages (from deafrica_tools) (1.17.0)
# Collecting fiona
#   Downloading Fiona-1.8.21-cp37-cp37m-manylinux2014_x86_64.whl (16.7 MB)
#      |████████████████████████████████| 16.7 MB 278 kB/s
# Requirement already satisfied: GDAL in /usr/local/lib/python3.7/dist-packages (from deafrica_tools) (2.2.2)
# Requirement already satisfied: branca in /usr/local/lib/python3.7/dist-packages (from deafrica_tools) (0.4.2)
# Requirement already satisfied: folium in /usr/local/lib/python3.7/dist-packages (from deafrica_tools) (0.8.3)
# Requirement already satisfied: shapely in /usr/local/lib/python3.7/dist-packages (from deafrica_tools) (1.8.1.post1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from deafrica_tools) (1.21.5)
# Collecting datetime
#   Downloading DateTime-4.4-py2.py3-none-any.whl (51 kB)
#      |████████████████████████████████| 51 kB 405 kB/s
# Collecting geopandas
#   Downloading geopandas-0.10.2-py2.py3-none-any.whl (1.0 MB)
#      |████████████████████████████████| 1.0 MB 41.2 MB/s
# Requirement already satisfied: numexpr in /usr/local/lib/python3.7/dist-packages (from deafrica_tools) (2.8.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from deafrica_tools) (4.63.0)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from deafrica_tools) (1.0.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from deafrica_tools) (1.3.5)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from deafrica_tools) (1.4.1)
# Requirement already satisfied: xarray in /usr/local/lib/python3.7/dist-packages (from deafrica_tools) (0.18.2)
# Collecting fsspec
#   Downloading fsspec-2022.3.0-py3-none-any.whl (136 kB)
#      |████████████████████████████████| 136 kB 45.6 MB/s
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.7/dist-packages (from deafrica_tools) (0.18.3)
# Requirement already satisfied: rasterio in /usr/local/lib/python3.7/dist-packages (from deafrica_tools) (1.2.10)
# Collecting hdstats
#   Downloading hdstats-0.2.1.tar.gz (543 kB)
#      |████████████████████████████████| 543 kB 43.5 MB/s
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# Requirement already satisfied: datacube in /usr/local/lib/python3.7/dist-packages (from deafrica_tools) (1.8.5)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.7/dist-packages (from deafrica_tools) (3.2.2)
# Collecting rasterstats
#   Downloading rasterstats-0.16.0-py3-none-any.whl (16 kB)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.7/dist-packages (from branca->deafrica_tools) (2.11.3)
# Requirement already satisfied: click>=5.0 in /usr/local/lib/python3.7/dist-packages (from datacube->deafrica_tools) (7.1.2)
# Requirement already satisfied: cloudpickle>=0.4 in /usr/local/lib/python3.7/dist-packages (from datacube->deafrica_tools) (1.3.0)
# Requirement already satisfied: affine in /usr/local/lib/python3.7/dist-packages (from datacube->deafrica_tools) (2.3.1)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.7/dist-packages (from datacube->deafrica_tools) (2.8.2)
# Requirement already satisfied: psycopg2 in /usr/local/lib/python3.7/dist-packages (from datacube->deafrica_tools) (2.7.6.1)
# Requirement already satisfied: distributed in /usr/local/lib/python3.7/dist-packages (from datacube->deafrica_tools) (1.25.3)
# Requirement already satisfied: toolz in /usr/local/lib/python3.7/dist-packages (from datacube->deafrica_tools) (0.11.2)
# Requirement already satisfied: netcdf4 in /usr/local/lib/python3.7/dist-packages (from datacube->deafrica_tools) (1.5.8)
# Requirement already satisfied: sqlalchemy in /usr/local/lib/python3.7/dist-packages (from datacube->deafrica_tools) (1.4.32)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.7/dist-packages (from datacube->deafrica_tools) (3.13)
# Requirement already satisfied: lark-parser>=0.6.7 in /usr/local/lib/python3.7/dist-packages (from datacube->deafrica_tools) (0.12.0)
# Requirement already satisfied: cachetools in /usr/local/lib/python3.7/dist-packages (from datacube->deafrica_tools) (4.2.4)
# Requirement already satisfied: jsonschema in /usr/local/lib/python3.7/dist-packages (from datacube->deafrica_tools) (4.3.3)
# Requirement already satisfied: certifi in /usr/local/lib/python3.7/dist-packages (from pyproj->deafrica_tools) (2021.10.8)
# Requirement already satisfied: snuggs>=1.4.1 in /usr/local/lib/python3.7/dist-packages (from rasterio->deafrica_tools) (1.4.7)
# Requirement already satisfied: click-plugins in /usr/local/lib/python3.7/dist-packages (from rasterio->deafrica_tools) (1.1.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from rasterio->deafrica_tools) (57.4.0)
# Requirement already satisfied: attrs in /usr/local/lib/python3.7/dist-packages (from rasterio->deafrica_tools) (21.4.0)
# Requirement already satisfied: cligj>=0.5 in /usr/local/lib/python3.7/dist-packages (from rasterio->deafrica_tools) (0.7.2)
# Requirement already satisfied: pyparsing>=2.1.6 in /usr/local/lib/python3.7/dist-packages (from snuggs>=1.4.1->rasterio->deafrica_tools) (3.0.7)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas->deafrica_tools) (2018.9)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil->datacube->deafrica_tools) (1.15.0)
# Collecting zope.interface
#   Downloading zope.interface-5.4.0-cp37-cp37m-manylinux2010_x86_64.whl (251 kB)
#      |████████████████████████████████| 251 kB 48.1 MB/s
# Requirement already satisfied: zict>=0.1.3 in /usr/local/lib/python3.7/dist-packages (from distributed->datacube->deafrica_tools) (2.1.0)
# Requirement already satisfied: psutil>=5.0 in /usr/local/lib/python3.7/dist-packages (from distributed->datacube->deafrica_tools) (5.4.8)
# Requirement already satisfied: tornado>=4.5.1 in /usr/local/lib/python3.7/dist-packages (from distributed->datacube->deafrica_tools) (5.1.1)
# Requirement already satisfied: sortedcontainers!=2.0.0,!=2.0.1 in /usr/local/lib/python3.7/dist-packages (from distributed->datacube->deafrica_tools) (2.4.0)
# Requirement already satisfied: tblib in /usr/local/lib/python3.7/dist-packages (from distributed->datacube->deafrica_tools) (1.7.0)
# Requirement already satisfied: msgpack in /usr/local/lib/python3.7/dist-packages (from distributed->datacube->deafrica_tools) (1.0.3)
# Requirement already satisfied: heapdict in /usr/local/lib/python3.7/dist-packages (from zict>=0.1.3->distributed->datacube->deafrica_tools) (1.0.1)
# Collecting munch
#   Downloading munch-2.5.0-py2.py3-none-any.whl (10 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from folium->deafrica_tools) (2.23.0)
# Requirement already satisfied: geographiclib<2,>=1.49 in /usr/local/lib/python3.7/dist-packages (from geopy->deafrica_tools) (1.52)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from jinja2->branca->deafrica_tools) (2.0.1)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.7/dist-packages (from jsonschema->datacube->deafrica_tools) (0.18.1)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from jsonschema->datacube->deafrica_tools) (4.11.3)
# Requirement already satisfied: importlib-resources>=1.4.0 in /usr/local/lib/python3.7/dist-packages (from jsonschema->datacube->deafrica_tools) (5.4.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from jsonschema->datacube->deafrica_tools) (3.10.0.2)
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.7/dist-packages (from importlib-resources>=1.4.0->jsonschema->datacube->deafrica_tools) (3.7.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.7/dist-packages (from matplotlib->deafrica_tools) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib->deafrica_tools) (1.4.0)
# Requirement already satisfied: cftime in /usr/local/lib/python3.7/dist-packages (from netcdf4->datacube->deafrica_tools) (1.6.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from numexpr->deafrica_tools) (21.3)
# Collecting ipyleaflet
#   Downloading ipyleaflet-0.15.0-py2.py3-none-any.whl (3.3 MB)
#      |████████████████████████████████| 3.3 MB 35.5 MB/s
# Collecting jupyter-ui-poll
#   Downloading jupyter_ui_poll-0.2.1-py2.py3-none-any.whl (9.0 kB)
# Requirement already satisfied: ipywidgets in /usr/local/lib/python3.7/dist-packages (from odc-ui->deafrica_tools) (7.7.0)
# Requirement already satisfied: ipython in /usr/local/lib/python3.7/dist-packages (from odc-ui->deafrica_tools) (5.5.0)
# Collecting odc-algo
#   Downloading odc_algo-0.2.2-py3-none-any.whl (51 kB)
#      |████████████████████████████████| 51 kB 6.4 MB/s
# Collecting traittypes<3,>=0.2.1
#   Downloading traittypes-0.2.1-py2.py3-none-any.whl (8.6 kB)
# Collecting xyzservices>=2021.8.1
#   Downloading xyzservices-2022.3.0-py3-none-any.whl (36 kB)
# Requirement already satisfied: ipykernel>=4.5.1 in /usr/local/lib/python3.7/dist-packages (from ipywidgets->odc-ui->deafrica_tools) (4.10.1)
# Requirement already satisfied: traitlets>=4.3.1 in /usr/local/lib/python3.7/dist-packages (from ipywidgets->odc-ui->deafrica_tools) (5.1.1)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.7/dist-packages (from ipywidgets->odc-ui->deafrica_tools) (3.6.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from ipywidgets->odc-ui->deafrica_tools) (1.1.0)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /usr/local/lib/python3.7/dist-packages (from ipywidgets->odc-ui->deafrica_tools) (0.2.0)
# Requirement already satisfied: nbformat>=4.2.0 in /usr/local/lib/python3.7/dist-packages (from ipywidgets->odc-ui->deafrica_tools) (5.2.0)
# Requirement already satisfied: jupyter-client in /usr/local/lib/python3.7/dist-packages (from ipykernel>=4.5.1->ipywidgets->odc-ui->deafrica_tools) (5.3.5)
# Requirement already satisfied: pexpect in /usr/local/lib/python3.7/dist-packages (from ipython->odc-ui->deafrica_tools) (4.8.0)
# Requirement already satisfied: pygments in /usr/local/lib/python3.7/dist-packages (from ipython->odc-ui->deafrica_tools) (2.6.1)
# Requirement already satisfied: prompt-toolkit<2.0.0,>=1.0.4 in /usr/local/lib/python3.7/dist-packages (from ipython->odc-ui->deafrica_tools) (1.0.18)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.7/dist-packages (from ipython->odc-ui->deafrica_tools) (0.7.5)
# Requirement already satisfied: decorator in /usr/local/lib/python3.7/dist-packages (from ipython->odc-ui->deafrica_tools) (4.4.2)
# Requirement already satisfied: simplegeneric>0.8 in /usr/local/lib/python3.7/dist-packages (from ipython->odc-ui->deafrica_tools) (0.8.1)
# Requirement already satisfied: jupyter-core in /usr/local/lib/python3.7/dist-packages (from nbformat>=4.2.0->ipywidgets->odc-ui->deafrica_tools) (4.9.2)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.7/dist-packages (from prompt-toolkit<2.0.0,>=1.0.4->ipython->odc-ui->deafrica_tools) (0.2.5)
# Requirement already satisfied: notebook>=4.4.1 in /usr/local/lib/python3.7/dist-packages (from widgetsnbextension~=3.6.0->ipywidgets->odc-ui->deafrica_tools) (5.3.1)
# Requirement already satisfied: nbconvert in /usr/local/lib/python3.7/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->odc-ui->deafrica_tools) (5.6.1)
# Requirement already satisfied: Send2Trash in /usr/local/lib/python3.7/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->odc-ui->deafrica_tools) (1.8.0)
# Requirement already satisfied: terminado>=0.8.1 in /usr/local/lib/python3.7/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->odc-ui->deafrica_tools) (0.13.3)
# Requirement already satisfied: pyzmq>=13 in /usr/local/lib/python3.7/dist-packages (from jupyter-client->ipykernel>=4.5.1->ipywidgets->odc-ui->deafrica_tools) (22.3.0)
# Requirement already satisfied: ptyprocess in /usr/local/lib/python3.7/dist-packages (from terminado>=0.8.1->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->odc-ui->deafrica_tools) (0.7.0)
# Requirement already satisfied: testpath in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->odc-ui->deafrica_tools) (0.6.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->odc-ui->deafrica_tools) (1.5.0)
# Requirement already satisfied: bleach in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->odc-ui->deafrica_tools) (4.1.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->odc-ui->deafrica_tools) (0.7.1)
# Requirement already satisfied: mistune<2,>=0.8.1 in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->odc-ui->deafrica_tools) (0.8.4)
# Requirement already satisfied: entrypoints>=0.2.2 in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->odc-ui->deafrica_tools) (0.4)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.7/dist-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->odc-ui->deafrica_tools) (0.5.1)
# Collecting dask-image
#   Downloading dask-image-2021.12.0.tar.gz (82 kB)
#      |████████████████████████████████| 82 kB 801 kB/s
# Collecting pims>=0.4.1
#   Downloading PIMS-0.5.tar.gz (85 kB)
#      |████████████████████████████████| 85 kB 3.8 MB/s
# Collecting slicerator>=0.9.8
#   Downloading slicerator-1.1.0-py3-none-any.whl (10 kB)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->folium->deafrica_tools) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->folium->deafrica_tools) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->folium->deafrica_tools) (2.10)
# Collecting simplejson
#   Downloading simplejson-3.17.6-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (130 kB)
#      |████████████████████████████████| 130 kB 37.2 MB/s
# Requirement already satisfied: imageio>=2.3.0 in /usr/local/lib/python3.7/dist-packages (from scikit-image->deafrica_tools) (2.4.1)
# Requirement already satisfied: tifffile>=2019.7.26 in /usr/local/lib/python3.7/dist-packages (from scikit-image->deafrica_tools) (2021.11.2)
# Requirement already satisfied: PyWavelets>=1.1.1 in /usr/local/lib/python3.7/dist-packages (from scikit-image->deafrica_tools) (1.3.0)
# Requirement already satisfied: pillow!=7.1.0,!=7.1.1,>=4.3.0 in /usr/local/lib/python3.7/dist-packages (from scikit-image->deafrica_tools) (7.1.2)
# Requirement already satisfied: networkx>=2.0 in /usr/local/lib/python3.7/dist-packages (from scikit-image->deafrica_tools) (2.6.3)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->deafrica_tools) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->deafrica_tools) (3.1.0)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.7/dist-packages (from sqlalchemy->datacube->deafrica_tools) (1.1.2)
# Building wheels for collected packages: hdstats, dask-image, pims
#   Building wheel for hdstats (PEP 517) ... done
#   Created wheel for hdstats: filename=hdstats-0.2.1-cp37-cp37m-linux_x86_64.whl size=2035434 sha256=e630d297652169ff887298ca175e549617b26e8cf56aeda1fa87e78f2440aea0
#   Stored in directory: /root/.cache/pip/wheels/5e/89/c0/fe80e047f4c93c69bf9bb6b6d2510323a8c9464f493315f67e
#   Building wheel for dask-image (setup.py) ... done
#   Created wheel for dask-image: filename=dask_image-2021.12.0-py2.py3-none-any.whl size=41037 sha256=8e1b657572efd3e4678796a3af54fb4bb15506f28f3097f65841b43c7ba94e11
#   Stored in directory: /root/.cache/pip/wheels/cf/76/0d/4fee9d7b0ebef879819c8dc020279bd9e1e73313eb30c10136
#   Building wheel for pims (setup.py) ... done
#   Created wheel for pims: filename=PIMS-0.5-py3-none-any.whl size=84325 sha256=eeba352c7c017b480b23e79d09a0b0b60d4e64c1d3bc4fde3533f9687ccbba8a
#   Stored in directory: /root/.cache/pip/wheels/75/02/a9/86571c38081ba4c1832eb95430b5d588dfa15a738e2a603737
# Successfully built hdstats dask-image pims
# Installing collected packages: slicerator, pims, xyzservices, traittypes, munch, dask-image, zope.interface, simplejson, odc-algo, jupyter-ui-poll, ipyleaflet, fiona, rasterstats, OWSLib, odc-ui, hdstats, geopandas, fsspec, datetime, deafrica-tools
# Successfully installed OWSLib-0.25.0 dask-image-2021.12.0 datetime-4.4 deafrica-tools-0.1.2 fiona-1.8.21 fsspec-2022.3.0 geopandas-0.10.2 hdstats-0.2.1 ipyleaflet-0.15.0 jupyter-ui-poll-0.2.1 munch-2.5.0 odc-algo-0.2.2 odc-ui-0.2.0a3 pims-0.5 rasterstats-0.16.0 simplejson-3.17.6 slicerator-1.1.0 traittypes-0.2.1 xyzservices-2022.3.0 zope.interface-5.4.0

# %%
# %matplotlib inline

import datacube
import numpy as np
import xarray as xr
import matplotlib.pyplot as plt

from deafrica_tools.load_era5 import load_era5
from deafrica_tools.datahandling import load_ard, mostcommon_crs
from deafrica_tools.plotting import rgb

# %%
dc = datacube.Datacube(app="Landsat_Surface_Temperature")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-49b6a45a664e> in <module>()
# ----> 1 dc = datacube.Datacube(app="Landsat_Surface_Temperature")
#
# /usr/local/lib/python3.7/dist-packages/datacube/api/core.py in __init__(self, index, config, app, env, validate_connection)
#      85
#      86         if index is None:
# ---> 87             index = index_connect(normalise_config(config),
#      88                                   application_name=app,
#      89                                   validate_connection=validate_connection)
#
# /usr/local/lib/python3.7/dist-packages/datacube/api/core.py in normalise_config(config)
#      79         def normalise_config(config):
#      80             if config is None:
# ---> 81                 return LocalConfig.find(env=env)
#      82             if isinstance(config, str):
#      83                 return LocalConfig.find([config], env=env)
#
# /usr/local/lib/python3.7/dist-packages/datacube/config.py in find(cls, paths, env)
#     133             config,
#     134             files_loaded=files_loaded,
# --> 135             env=env,
#     136         )
#     137
#
# /usr/local/lib/python3.7/dist-packages/datacube/config.py in __init__(self, config, files_loaded, env)
#     103                     self._env = fallback_env
#     104                     return
# --> 105             raise ValueError('No ODC environment, checked configurations for %s' % fallbacks)
#     106
#     107     @classmethod
#
# ValueError: No ODC environment, checked configurations for ['default', 'datacube']
